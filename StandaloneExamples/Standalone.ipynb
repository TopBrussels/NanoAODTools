# %% [markdown]
# Use Shift+Enter to execute each cell
#
# Try to make our code python-3 friendlier for future implementation and grab the import function

# %%
from __future__ import (division,
                        print_function,
                        #unicode_literals,
                       )
from importlib import import_module

# %% [markdown]
# Import useful functions we may want

# %%
import os, sys, time

# %% [markdown]
# We need ROOT's functionality...

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.10/09

# %% [markdown]
# Import the PostProcessor, the framework for running on NanoAOD

# %%
from PhysicsTools.NanoAODTools.postprocessing.framework.postprocessor import PostProcessor

# %% [markdown]
# We want the Module Class, and Collection/Object helper methods

# %%
from PhysicsTools.NanoAODTools.postprocessing.framework.datamodel import Collection, Object
from PhysicsTools.NanoAODTools.postprocessing.framework.eventloop import Module

# %% [markdown]
# Here we define our class module, which we'll load/configure near the bottom, then finally run.
# This inherits from the base class "Module."
# Where we do 'def beginJob' or 'def analyze,' we override the base Module's definition with our own.
# We can name our class almost anything, so long as it matches the name that we pass to the PostProcessor(p=PostProcessor(...) definition near the end), which will create an instances of this class to be used in the analysis chain

# %%
class OurExampleModule(Module):
    def __init__(self):
        self.writeHistFile=True #Necessary for an output file to be created? 
        self.counter = 0 #Define this global variable to count events
        self.EventLimit = -1
        self.isData = False #For running on data versus MonteCarlo
    def beginJob(self,histFile=None,histDirName=None):
        #beginJob is typically where histograms should be initialized
        #So we call the default Module's beginJob, passing it the histFile and histDirName first passed to the PostProcessor
        Module.beginJob(self,histFile,histDirName)
        #Here, create a 1-D histogram of type Double(TH1D)
        #with histogram_name h_jets, and someTitle(title)/nJets(x-axis)/Events(y-axis), 20 bins, with domain 0 to 20
        self.h_jets = ROOT.TH1D('h_jets', 'someTitle;nJets;Events',   20, 0, 20)
        #The histogram has to be 'booked' with the service that will write everything to the output file
        self.addObject(self.h_jets)
        #Repeat for other histograms
        self.h_fatjets = ROOT.TH1D('h_fatjets', ';nFatJets;Events', 8, 0, 8)
        self.addObject(self.h_fatjets)
        self.h_subjets = ROOT.TH1D('h_subjets', ';nSubJets;Events', 16, 0, 16)
        self.addObject(self.h_subjets)
        
    #We can override the other processes with "pass,"
    #If we do this for endFile, histograms won't be written    
    #def endJob(self):
    #    pass

    #def beginFile(self, inputFile, outputFile):
    #    pass

    #def beginFile(self):
    #    pass

    #def endFile(self, inputFile, outputFile):
    #    pass

    #def endFile(self):
    #    pass
    
    def analyze(self, event):
        #DOC string for our analyze method, denoted by triple-quotes
        """process event, return True (go to next module) or False (fail, go to next event)"""
        
        self.h_jets.Fill(event.nJet)
        self.h_fatjets.Fill(event.nFatJet)
        self.h_subjets.Fill(event.nSubJet)
        
        modulator = 1000 # how often to print an event when we do self.counter % modulator
        self.counter += 1
        
        #Below we 'halt' execution for events past the first N (20 when written) by returning False now 
        if self.counter > self.EventLimit > -1:
            return False
        
        ###########################################
        ###### Basic Attributes of the Event ######
        ###########################################
        #Use basic python getattr() method to grab this info, no need for Object or Collection here
        run = getattr(event, "run")
        lumi = getattr(event, "luminosityBlock")
        evt = getattr(event, "event")
        #if self.counter % modulator == 0:
        print("\n\nRun: {0:>8d} \tLuminosityBlock: {1:>8d} \tEvent: {2:>8d}".format(run,lumi,evt)) 
    
        ###########################################
        ###### Event Collections and Objects ######
        ###########################################
        #Collections are for variable-length objects, easily identified by a nVARIABLE object in the NanoAOD file ("nJet")
        #Objects are for 1-deep variables, like HLT triggers, where there are many of them, but there is only one boolean value
        #for each HLT_SomeSpecificTrigger for each event. These are more than just wrappers, providing convenient methods
        #This will 'work' for anything that has some common name + '_' (like "SV_x" and "SV_y" and "SV_z")
        #Objects:
        met = Object(event, "MET")
        PV = Object(event, "PV")
        HLT = Object(event, "HLT") 
        Filters = Object(event, "Flag")
        #Collections:
        electrons = Collection(event, "Electron")
        photons = Collection(event, "Photon")
        muons = Collection(event, "Muon")
        #taus = Collection(event, "Tau") 
        jets = Collection(event, "Jet")
        fatjets = Collection(event, "FatJet")
        subjets = Collection(event, "SubJet")
        SV = Collection(event, "SV") 
        if not self.isData:
            gens = Collection(event, "GenPart")
            genJets = Collection(event, "GenJet")
            genFatjets = Collection(event, "GenJetAK8")
            genSubjets = Collection(event, "SubGenJetAK8")
    
        ################################
        ###### High Level Trigger ######
        ################################
        passTrig=["IsoMu20", "IsoMu24"] #Create a list of valid triggers to check, dropping "HLT_"
        if self.counter % modulator == 0:
            for trig in passTrig:
                print("\tHLT_" + str(trig) + " Trigger: " + str(getattr(HLT, trig)) )


        ###############################
        ######### MET Filters #########
        ###############################
        if self.isData:
            #All the filters commonly used
            passFilter=["HBHENoiseFilter", "HBHENoiseIsoFilter", "EcalDeadCellTriggerPrimitiveFilter",
                    "globalSuperTightHalo2016Filter", "goodVertices", "METFilters", "noBadMuons"] 
            #if self.counter % modulator == 0:
            for fltr in passFilter:
                print("\t\tFlag_" + str(fltr) + " Filter: " + str(getattr(Filters, fltr)))
                

        ###############################
        ###### Time To Do Stuff! ######
        ###############################
        #Create a TLorentzVector to sum the four-momentum in the event (but don't doublecount by adding Fat/SubJets!)
        eventSum = ROOT.TLorentzVector()
        #Below is a formatted output of the Primary Vertex's coordinates, number of Degrees of Freedom, Chi^2 value
        print("PV  X: {0: >5.3f} Y: {1: >5.3f} Z: {2:5.3f} nDoF: {3: >5.3f} Chi^2: {4: >5.3f}".format(
            PV.x,PV.y, PV.z, PV.ndof, PV.chi2)) #getattr(PV, "chi2") also works
        
        #Now we wish to count and print info about the secondary vertices (heavy flavour hadrons!) in the event, including decay length
        print("==============================================================================")
        print("|| Secondary Vertices\tNumber: {0: >3d} \t\t\t\t\t    ||".format(len(SV)))
        if len(SV) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t{5:>5s}\t{6:>5s}\t\t    ||".format(
                "Pt", "Eta", "Phi", "Chi2", "nDoF", "Mass", "dLen"))
            for vert in SV:
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t{5: >5.3f}\t{6: >5.3f}\t\t    ||".format(
                    getattr(vert,"pt"),getattr(vert,"eta"),getattr(vert,"phi"),
                    getattr(vert,"chi2"),getattr(vert,"ndof"),getattr(vert,"mass"),getattr(vert,"dlen")))
                
        #Now the Muons, where JetID is the array index of any jet that matches in eta-phi space (to be used for cross-cleaning)
        print("==============================================================================")
        print("|| Muons\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(muons)))
        if len(muons) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t{5:>5s}\t{6:>5s}\t{7:>5s}  ||".format(
                    "Pt", "Eta", "Phi", "IP3d", "dXY", "dZ", "JetID", "PFRelIso04"))
            for lep in muons:
                eventSum += lep.p4()
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t{5: >5.3f}\t{6: >5d}\t{7: >5.3f}\t    ||".format(
                        getattr(lep,"pt"),getattr(lep,"eta"),getattr(lep,"phi"),getattr(lep,"ip3d"),
                        getattr(lep,"dxy"),getattr(lep,"dz"),getattr(lep,"jetIdx"),getattr(lep,"pfRelIso04_all")))
        print("==============================================================================")
        print("|| Electrons\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(electrons)))
        if len(electrons) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t{5:>5s}\t{6:>5s}\t{7:>5s}  ||".format(
                    "Pt", "Eta", "Phi", "IP3d", "dXY", "dZ", "JetID", "PFRelIso03"))
            for lep in electrons:
                eventSum += lep.p4()
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t{5: >5.3f}\t{6: >5d}\t{7: >5.3f}\t    ||".format(
                        getattr(lep,"pt"),getattr(lep,"eta"),getattr(lep,"phi"),getattr(lep,"ip3d"),
                        getattr(lep,"dxy"),getattr(lep,"dz"),getattr(lep,"jetIdx"),getattr(lep,"pfRelIso03_all")))
        #Now the photons. Note whether it passes electronVeto, the electron it may be ID-linked with, etc.
        print("==============================================================================")
        print("|| Photons\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(photons)))
        if len(photons) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{5:>5s}\t{6:>5s}\t{7:>5s}\t{4:>5s}  ||".format(
                    "Pt", "Eta", "Phi", "mvaID", "PFRelIso03", "e ID", "JetID", "eVeto"))
            for gamma in photons:
                #eventSum += gamma.p4()
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5d}\t{5: >5d}\t{6: >5d}\t{7: >5.3f}\t    ||".format(
                        getattr(gamma,"pt"),getattr(gamma,"eta"),getattr(gamma,"phi"),getattr(gamma,"mvaID_WP80"),
                        getattr(gamma,"electronIdx"),getattr(gamma,"jetIdx"),getattr(gamma,"electronVeto"),
                        getattr(gamma,"pfRelIso03_all")))
        #Below we'll print info like the CombinedSecondaryVertex Version 2 b-tagging output, the charged electromagnetic and hadron energy fractions...
        print("==============================================================================")
        #for j in filter(self.jetSel,jets):
        print("|| AK4 Jets\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(jets)))
        print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t{5:>5s}\t{6:>5s}\t{7:>5s}       ||".format(
                "Pt", "Eta", "Phi", "CSVv2", "CMVA", "JetID", "ChEmEF", "ChHEF"))
        for jet in jets:
            eventSum += jet.p4()
            print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t{5: >5d}\t{6: >5.3f}\t{7: >5.3f}\t    ||".format(
                    getattr(jet,"pt"),getattr(jet,"eta"),getattr(jet,"phi"),getattr(jet,"btagCSVV2"),
                    getattr(jet,"btagCMVA"),getattr(jet,"jetId"),getattr(jet,"chEmEF"),getattr(jet,"chHEF")))
        print("==============================================================================")
        print("|| AK8 Jets\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(fatjets)))
        if len(fatjets) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t{5:>5s}\t{6:>5s}\t{7:>5s}       ||".format(
                    "Pt", "Eta", "Phi", "CSVv2", "Mass", "MSDrp", "sJID1", "sJID2"))
            for fjet in fatjets:
                #Don't sum these in the event, as they're just reclustering of the same energy deposits used to construct "jets"
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t{5: >5.3f}\t{6: >5d}\t{7: >5d}\t    ||".format(
                        getattr(fjet,"pt"),getattr(fjet,"eta"),getattr(fjet,"phi"),getattr(fjet,"btagCSVV2"),
                        getattr(fjet,"mass"),getattr(fjet,"msoftdrop"),getattr(fjet,"subJetIdx1"),
                        getattr(fjet,"subJetIdx2")))
        print("==============================================================================")
        print("|| AK8 SubJets\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(subjets)))
        if len(subjets) > 0:
            print("||\t{0:>5s}\t{1:>5s}\t{2:>5s}\t{3:>5s}\t{4:>5s}\t\t\t\t    ||".format(
                    "Pt", "Eta", "Phi", "CSVv2","Mass"))
            for sjet in subjets:
                #Ditto here, no sum, since these should correspond to "jets" in the AK4 collection
                print("||\t{0: >5.3f}\t{1: >5.3f}\t{2: >5.3f}\t{3: >5.3f}\t{4: >5.3f}\t\t\t\t    ||".format(
                        getattr(sjet,"pt"),getattr(sjet,"eta"),getattr(sjet,"phi"),getattr(sjet,"btagCSVV2"),
                        getattr(sjet,"mass")))
        print("==============================================================================")
        if not self.isData:
            print("|| Gen particles\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(gens)))
            print("|| AK4 genjets\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(genJets)))
            print("|| AK8 genjets\t\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(genFatjets)))
            print("|| AK8 genSubjets\tNumber: {0: >3d}\t\t\t\t\t    ||".format(len(genSubjets)))
            print("==============================================================================")
        print("Event Mass: {:<10.4f}\n".format(eventSum.M()))
        
        ###########################################
        ###### Return True to pass the event ######
        ###########################################
        return True

# %% [markdown]
# We can do a preselection on any element in the file, e.g. requiring at least one detectable lepton shows up, like so...

# %%
preselection="nMuon > 0 || nElectron > 0"

#For when we want to loop over every event, and let the analyzer choose to pass/fail the event:
#preselection=None

# %% [markdown]
# Here, define the location where we'll output any root files, "." meaning the current directory from which the code is run.

# %%
outputDir = "."
#outputDir = "../path/of/choice"

# %% [markdown]
# Create our list of files to be processed, first by creating a prefix for our files list, because we copy those directly from Data Aggragation Service, and it does not include a server reference for the files. Postfix should be paired with the corresponding inputList, which will be added to any root files output (either histogram file or full NanoAOD file of events passing full analyze chain ("return True")

# %%
filePrefix = "root://cms-xrd-global.cern.ch/"
files=[]
#Open the text list of files as read-only ("r" option), use as pairs to add proper postfix to output file
inputList =  open("Infiles/TTJets_SingleLeptFromT_TuneCP5_13TeV-madgraphMLM-pythia8.txt", "r") # tt + jets MC
thePostFix = "TTJets_SL"
#inputList =  open("Infiles/TTTT_TuneCP5_13TeV-amcatnlo-pythia8.txt", "r") # tttt MC
#thePostFix = "TTTT"
#inputList =  open("Infiles/TTTT_TuneCP5_PSweights_13TeV-amcatnlo-pythia8.txt", "r") # tttt MC PSWeights
#thePostFix = "TTTT_PSWeights"
#inputList =  open("Infiles/WJetsToLNu_TuneCP5_13TeV-madgraphMLM-pythia8.txt", "r") # W (to Lep + Nu) + jets
#thePostFix = "WJetsToLNu"

for line in inputList:
    #.replace('\n','') protects against new line characters at end of filenames, use just str(line) if problem appears
    files.append(filePrefix + str(line).replace('\n',''))

#Uncomment the two lines here to see what's being added to the list
#for file in files: 
#    print(file)

# %% [markdown]
# Below we'll create a single file, for speedier testing. Additionally, using root to open this file will let you browse its content. Use "new TBrowser" in root, once it has opened and attached the file.

# %%
#option to experiment with only the first file in the above list
onefile = [files[0]] 
print(onefile[0])
# Out:
# root://cms-xrd-global.cern.ch//store/mc/RunIIFall17NanoAOD/TTJets_SingleLeptFromT_TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/00000/06CC0D9B-4244-E811-8B62-485B39897212.root

# %% [markdown]
# For running on Data, we would should do a few things:
#
# <ol>
#     <li>Include a valid JSON file, which we'll define below. This rejects events from times when CMS's subdetectors were in unacceptable states.</li>
#     <li>Switch our inputList to some valid data!</li>
#     <li>Toggle the isData boolean inside the instance of our class (either manually above, or after creating our postprocessor below)</li>
# </ol>

# %%
#For Monte Carlo:
theJSON = None

#For Data:
#theJSON = "Infiles/Cert_294927-306462_13TeV_EOY2017ReReco_Collisions17_JSON.txt"

# %% [markdown]
# Here we define the postprocessor with everything getting loaded, from files to JsonFile. "Named" options should have a default value, i.e. justcount's default is already False. Not all options are orthogonal.
#
#  <ul>
#   <li>outputDir: Defined above, this is where root files will be written. Can substitute "." for outputDir directly.</li>
#   <li>jsonInput: json file in dictionary format {"RunNumberInt": [[lumilow,lumihigh],[lumi2low,lumi2high]], "RunNumber2Int":[[low,high]]}, using a string containing the relative path to the JSON's location</li>
#   <li>files: list ["fileone.root","filetwo.root"] of inputs; even if just one file, must be a list! May point to a file to be accessed over XRD (make sure your proxy is valid!)</li>
# <li>branchsel: if non-None, selection of branches to not even activate/load into memory, more efficient I/O and speed-wise</li>
# <li>outputbranchsel: if non-None, selection of branches to keep/drop in output (see noOut)</li>
# <li>noOut: If True, no output of skimmed data is written. If False, will write full data file fitting outputbranch selections and with postfix concattenated to name. Independant of histFile.</li>
# <li>justCount: Just counts events fitting preselection criteria, analyze() criteria not taken into account</li>
# <li>postfix: string added to inputfile name to indicate this module processed it!</li>
# <li>histFileName: name of any output file for histograms created in your class, as above with runs and lumis</li>
# <li>histDirName: name INSIDE the "histFileName.root" file's directory structure!</li>
# <li>friend: Can be used to create "friend" trees to pair with original NanoAOD files.</li>
# <li>provenance: not tested</li>
# <li>haddFileName: Not properly tested (tied together with fwkJobReport)</li>
# <li>fwkJobReport: only relevant with multiple files being added together? Not properly tested</li>
# </ul>

# %%
p=PostProcessor(outputDir,
                onefile,
                cut=preselection,
                branchsel=None,
                modules=[OurExampleModule()],
                friend=False,
                postfix=thePostFix, 
                jsonInput=theJSON,
                noOut=True,
                justcount=False,
                provenance=False,
                haddFileName=None,
                fwkJobReport=False,
                histFileName="OurModuleHist.root",
                histDirName="plotsDirectory", 
                outputbranchsel=None
               )

# %% [markdown]
# Here is an example of accessing 'externally' the class instance's variable isData

# %%
print("On instantiation, the isData boolean is...\nFlag isData = " + str(p.modules[0].isData))
#p.modules[0].isData = True #Access isData variable in the main class (loaded as first module in postprocessor)
print("\nSet to...\nFlag isData = " + str(p.modules[0].isData))
# Out:
# On instantiation, the isData boolean is...
# Flag isData = False
#
# Set to...
# Flag isData = False

# %% [markdown]
# Before executing, let's set a limit on the number of events to run our full code over, as the default of -1 means all:

# %%
print("Initialized Event Limit: " + str(p.modules[0].EventLimit))
p.modules[0].EventLimit = 10
print("Set Event Limit: " + str(p.modules[0].EventLimit))
# Out:
# Initialized Event Limit: -1
# Set Event Limit: 10

# %% [markdown]
# Now that everything is defined, we'll actually run the process and see its direct output:

# %%
p.run()
# Out:
# Pre-select 636713 entries out of 696370
# /afs/cern.ch/work/n/nmangane/scratch1/CMSSW_9_4_9/python/PhysicsTools/NanoAODTools/postprocessing/framework/treeReaderArrayTools.py:69: RuntimeWarning: creating executor for unknown type "ULong64_t*"
#   ret = _vr.Get()[0]
# Run:        1 	LuminosityBlock:       59 	Event:   167594
# PV  X: -0.026 Y: 0.067 Z: 1.515 nDoF: 148.000 Chi^2: 0.814
# ==============================================================================
# || Secondary Vertices	Number:   3 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	8.109	-0.206	-0.351	0.401	6.750	1.988	0.035		    ||
# ||	48.656	-0.392	-0.429	2.039	4.297	2.598	0.220		    ||
# ||	27.000	1.325	-1.658	1.301	6.094	2.936	2.328		    ||
# ==============================================================================
# || Muons		Number:   2					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	40.590	-1.030	0.103	0.000	0.000	-0.000	    2	0.024	    ||
# ||	16.977	1.275	-1.651	0.086	0.011	0.165	    3	0.156	    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	4.987	-1.968	0.051	0.007	0.006	0.013	    7	0.601	    ||
# ==============================================================================
# || Photons		Number:   0					    ||
# ==============================================================================
# || AK4 Jets		Number:  10					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	139.500	0.559	-3.032	0.069	-0.979	    6	0.000	0.625	    ||
# ||	88.062	-0.325	-0.408	0.991	0.997	    6	0.000	0.766	    ||
# ||	47.031	-1.032	0.104	-10.000	-0.977	    6	0.000	0.064	    ||
# ||	35.062	1.309	-1.680	0.998	1.000	    6	0.000	0.379	    ||
# ||	33.281	1.504	2.369	0.164	-0.949	    6	0.000	0.562	    ||
# ||	30.703	-1.474	0.964	0.146	-0.974	    6	0.000	0.844	    ||
# ||	22.438	-1.798	2.875	0.528	-0.856	    6	0.000	0.664	    ||
# ||	16.844	-2.082	0.078	0.203	-0.968	    6	0.324	0.223	    ||
# ||	16.391	-1.324	2.888	0.528	-0.856	    6	0.270	0.336	    ||
# ||	16.375	-1.889	-1.689	0.289	-0.852	    6	0.000	0.449	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  36					    ||
# || AK4 genjets		Number:   7					    ||
# || AK8 genjets		Number:   1					    ||
# || AK8 genSubjets	Number:   2					    ||
# ==============================================================================
# Event Mass: 870.5423
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167628
# PV  X: -0.024 Y: 0.068 Z: 1.558 nDoF: 63.000 Chi^2: 0.525
# ==============================================================================
# || Secondary Vertices	Number:   4 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	25.391	0.137	-2.742	1.793	2.453	1.199	1.649		    ||
# ||	7.684	-0.210	-0.709	1.008	0.912	0.682	0.152		    ||
# ||	24.750	-1.249	1.299	0.396	2.875	1.048	2.621		    ||
# ||	7.129	-1.242	1.299	0.611	0.926	0.751	0.249		    ||
# ==============================================================================
# || Muons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	42.561	0.989	-1.685	0.001	-0.001	0.000	    2	0.000	    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	11.377	-1.208	1.287	0.066	0.018	-0.116	    1	2.220	    ||
# ==============================================================================
# || Photons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	mvaID	 e ID	JetID	eVeto	PFRelIso03  ||
# ||	12.874	-2.409	-0.630	0.000	   -1	    3	    1	0.763	    ||
# ==============================================================================
# || AK4 Jets		Number:   7					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	70.312	0.173	-2.702	0.999	1.000	    6	0.000	0.664	    ||
# ||	69.250	-1.224	1.295	0.983	0.998	    6	0.184	0.473	    ||
# ||	48.031	0.989	-1.676	0.075	-0.976	    6	0.000	0.024	    ||
# ||	43.562	-2.398	-0.553	0.692	-0.222	    6	0.066	0.414	    ||
# ||	28.672	-2.984	2.199	-10.000	-0.853	    6	0.000	0.021	    ||
# ||	16.094	2.853	-2.548	0.481	-0.610	    0	0.000	0.312	    ||
# ||	15.391	-3.176	1.204	-10.000	-0.853	    6	0.000	0.000	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  51					    ||
# || AK4 genjets		Number:   6					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 1064.8664
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167584
# PV  X: -0.024 Y: 0.070 Z: 0.087 nDoF: 119.250 Chi^2: 0.721
# ==============================================================================
# || Secondary Vertices	Number:   1 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	15.125	-2.128	2.459	2.000	2.617	1.146	3.086		    ||
# ==============================================================================
# || Muons		Number:   2					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	23.747	-2.021	2.339	0.000	0.000	-0.001	    0	1.215	    ||
# ||	3.456	-2.044	2.407	0.039	-0.022	-0.126	    0	7.087	    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	21.040	-2.119	-0.617	0.754	-0.753	0.086	    1	1.188	    ||
# ==============================================================================
# || Photons		Number:   0					    ||
# ==============================================================================
# || AK4 Jets		Number:   8					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	90.250	-2.071	2.412	0.979	0.997	    6	0.000	0.484	    ||
# ||	75.000	-2.073	-0.702	0.086	-0.983	    6	0.000	0.734	    ||
# ||	41.406	-3.473	-1.909	-10.000	-0.853	    6	0.000	0.000	    ||
# ||	38.906	-2.687	0.145	0.951	0.861	    6	0.000	0.414	    ||
# ||	23.203	-0.546	0.227	0.172	-0.961	    6	0.000	0.680	    ||
# ||	22.344	5.051	0.751	-10.000	-0.853	    0	0.000	0.000	    ||
# ||	21.656	2.655	-2.126	0.797	-0.046	    6	0.000	0.656	    ||
# ||	20.984	-2.983	-0.757	-10.000	-0.853	    6	0.000	0.014	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  49					    ||
# || AK4 genjets		Number:   6					    ||
# || AK8 genjets		Number:   1					    ||
# || AK8 genSubjets	Number:   2					    ||
# ==============================================================================
# Event Mass: 3948.4669
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167607
# PV  X: -0.024 Y: 0.069 Z: 3.444 nDoF: 160.500 Chi^2: 0.871
# ==============================================================================
# || Secondary Vertices	Number:   2 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	34.094	0.428	-1.190	1.113	2.898	1.816	0.432		    ||
# ||	25.109	-1.552	2.738	0.091	2.906	1.016	1.336		    ||
# ==============================================================================
# || Muons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	29.974	-0.066	2.786	0.008	-0.006	0.006	    3	0.149	    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	7.989	0.404	1.367	0.003	0.002	0.002	    5	2.368	    ||
# ==============================================================================
# || Photons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	mvaID	 e ID	JetID	eVeto	PFRelIso03  ||
# ||	77.750	0.424	-1.228	0.000	   -1	    0	    1	0.670	    ||
# ==============================================================================
# || AK4 Jets		Number:   7					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	155.875	0.441	-1.215	0.989	0.999	    6	0.000	0.617	    ||
# ||	71.438	-1.568	2.743	0.936	0.983	    6	0.073	0.664	    ||
# ||	36.250	0.318	1.726	0.835	0.250	    6	0.000	0.734	    ||
# ||	36.156	-0.034	2.789	0.186	-0.903	    6	0.000	0.039	    ||
# ||	34.344	-0.497	-1.425	0.161	-0.928	    6	0.000	0.852	    ||
# ||	24.922	0.403	1.224	0.324	-0.806	    6	0.000	0.719	    ||
# ||	17.156	-0.938	-0.465	0.127	-0.982	    6	0.000	0.828	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  51					    ||
# || AK4 genjets		Number:   9					    ||
# || AK8 genjets		Number:   1					    ||
# || AK8 genSubjets	Number:   2					    ||
# ==============================================================================
# Event Mass: 540.2219
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167616
# PV  X: -0.025 Y: 0.068 Z: -3.046 nDoF: 87.500 Chi^2: 0.762
# ==============================================================================
# || Secondary Vertices	Number:   4 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	14.023	-0.673	-1.215	1.781	0.883	0.936	0.103		    ||
# ||	15.773	0.897	-0.028	1.910	2.469	2.422	0.153		    ||
# ||	19.531	-0.542	-2.796	0.865	12.344	2.387	0.928		    ||
# ||	5.539	-0.622	-2.806	0.036	0.941	0.760	0.067		    ||
# ==============================================================================
# || Muons		Number:   2					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	93.886	-0.779	1.793	0.000	0.000	0.000	    0	0.000	    ||
# ||	11.366	0.958	-0.072	0.007	-0.002	-0.010	    5	0.565	    ||
# ==============================================================================
# || Electrons		Number:   0					    ||
# ==============================================================================
# || Photons		Number:   0					    ||
# ==============================================================================
# || AK4 Jets		Number:   8					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	101.250	-0.781	1.785	0.087	-0.970	    6	0.000	0.012	    ||
# ||	52.406	-0.608	-1.202	0.678	-0.448	    6	0.000	0.508	    ||
# ||	40.469	-0.574	-2.805	0.997	1.000	    6	0.000	0.867	    ||
# ||	39.969	0.523	-2.088	0.126	-0.976	    6	0.000	0.812	    ||
# ||	31.188	-1.697	0.590	-10.000	-0.953	    6	0.000	0.664	    ||
# ||	20.469	0.940	-0.019	0.931	0.935	    6	0.000	0.367	    ||
# ||	19.109	-2.594	-1.486	-10.000	-0.853	    6	0.000	0.430	    ||
# ||	16.953	-1.325	-0.164	0.131	-0.866	    6	0.000	0.820	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  38					    ||
# || AK4 genjets		Number:   7					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 578.2281
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167588
# PV  X: -0.026 Y: 0.068 Z: 1.298 nDoF: 127.000 Chi^2: 0.691
# ==============================================================================
# || Secondary Vertices	Number:   1 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	4.141	-0.117	1.501	0.006	0.943	0.370	0.679		    ||
# ==============================================================================
# || Muons		Number:   0					    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	22.164	0.777	3.082	0.013	-0.013	0.003	    3	0.024	    ||
# ==============================================================================
# || Photons		Number:   3					    ||
# ||	   Pt	  Eta	  Phi	mvaID	 e ID	JetID	eVeto	PFRelIso03  ||
# ||	34.120	0.691	-1.738	0.000	   -1	    0	    1	0.554	    ||
# ||	22.934	-0.253	1.510	0.000	   -1	    1	    1	0.402	    ||
# ||	21.564	0.779	3.048	0.000	    0	    3	    0	0.067	    ||
# ==============================================================================
# || AK4 Jets		Number:   8					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	63.812	0.726	-1.727	0.546	-0.464	    6	0.055	0.213	    ||
# ||	57.750	-0.180	1.553	0.996	1.000	    6	0.000	0.531	    ||
# ||	30.875	2.433	-0.916	0.555	-0.865	    6	0.000	0.992	    ||
# ||	29.594	0.793	3.096	0.269	-0.899	    6	0.719	0.081	    ||
# ||	21.469	-2.835	2.530	0.529	-0.872	    6	0.000	0.215	    ||
# ||	19.016	1.744	2.570	0.768	-0.399	    6	0.000	0.875	    ||
# ||	18.500	1.610	0.431	0.184	-0.973	    6	0.000	0.734	    ||
# ||	18.016	2.827	2.862	0.441	-0.879	    6	0.000	0.367	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  47					    ||
# || AK4 genjets		Number:   8					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 757.5531
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167595
# PV  X: -0.026 Y: 0.068 Z: 0.167 nDoF: 212.000 Chi^2: 0.605
# ==============================================================================
# || Secondary Vertices	Number:   4 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	2.033	-1.675	-2.144	1.816	0.881	0.500	0.683		    ||
# ||	2.521	1.482	1.949	0.592	0.926	0.502	0.193		    ||
# ||	2.795	0.548	-1.608	0.229	0.951	0.485	1.925		    ||
# ||	4.582	0.361	1.984	2.602	3.875	1.395	0.129		    ||
# ==============================================================================
# || Muons		Number:   0					    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	15.235	0.335	-1.563	0.122	-0.054	0.116	    2	1.799	    ||
# ==============================================================================
# || Photons		Number:   2					    ||
# ||	   Pt	  Eta	  Phi	mvaID	 e ID	JetID	eVeto	PFRelIso03  ||
# ||	18.370	0.398	-1.751	0.000	    0	    2	    0	1.395	    ||
# ||	14.374	-1.377	0.015	0.000	   -1	    3	    1	0.162	    ||
# ==============================================================================
# || AK4 Jets		Number:   6					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	108.750	0.401	1.815	0.885	0.361	    6	0.000	0.418	    ||
# ||	56.719	-0.338	-0.180	0.112	-0.970	    6	0.000	0.688	    ||
# ||	54.875	0.344	-1.617	0.822	0.931	    6	0.285	0.305	    ||
# ||	25.797	-1.440	0.013	0.462	-0.595	    6	0.000	0.336	    ||
# ||	19.328	-1.526	-2.660	0.198	-0.959	    6	0.000	0.398	    ||
# ||	15.039	3.196	-1.482	-10.000	-0.853	    6	0.000	0.000	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  76					    ||
# || AK4 genjets		Number:   8					    ||
# || AK8 genjets		Number:   1					    ||
# || AK8 genSubjets	Number:   2					    ||
# ==============================================================================
# Event Mass: 523.3308
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167635
# PV  X: -0.025 Y: 0.070 Z: -2.490 nDoF: 138.500 Chi^2: 0.781
# ==============================================================================
# || Secondary Vertices	Number:   3 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	3.432	-2.391	0.439	1.414	0.896	0.804	0.469		    ||
# ||	12.688	0.136	-2.162	0.101	0.939	1.134	0.072		    ||
# ||	22.578	0.602	0.431	1.086	8.500	1.813	0.170		    ||
# ==============================================================================
# || Muons		Number:   0					    ||
# ==============================================================================
# || Electrons		Number:   4					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	83.183	-0.655	-3.016	0.003	-0.001	0.003	    0	0.003	    ||
# ||	10.247	2.211	-1.871	1.221	-0.005	-5.637	    7	0.000	    ||
# ||	6.928	1.423	2.137	0.005	0.001	0.010	    2	1.307	    ||
# ||	6.420	2.200	-2.182	1.232	-0.004	-5.633	   -1	0.000	    ||
# ==============================================================================
# || Photons		Number:   3					    ||
# ||	   Pt	  Eta	  Phi	mvaID	 e ID	JetID	eVeto	PFRelIso03  ||
# ||	83.303	-0.655	-3.028	1.000	    0	    0	    0	0.001	    ||
# ||	29.730	1.186	2.445	0.000	   -1	    2	    1	0.577	    ||
# ||	15.571	1.796	0.903	0.000	   -1	    4	    1	0.819	    ||
# ==============================================================================
# || AK4 Jets		Number:  10					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	89.938	-0.654	-3.017	-10.000	-0.889	    2	0.992	0.006	    ||
# ||	76.188	0.712	0.357	0.925	0.774	    6	0.000	0.797	    ||
# ||	62.656	1.229	2.372	0.312	-0.930	    6	0.000	0.523	    ||
# ||	55.906	0.165	-2.251	0.450	-0.867	    6	0.000	0.773	    ||
# ||	49.156	1.794	0.914	0.109	-0.977	    6	0.000	0.633	    ||
# ||	39.094	3.896	1.646	-10.000	-0.853	    6	0.000	0.000	    ||
# ||	35.438	-1.446	-0.338	0.126	-0.978	    6	0.000	0.758	    ||
# ||	21.594	2.288	-1.893	0.543	-0.856	    6	0.656	0.348	    ||
# ||	19.422	3.400	-1.737	-10.000	-0.853	    6	0.000	0.000	    ||
# ||	19.391	-2.419	-0.386	0.289	-0.716	    6	0.000	1.000	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  41					    ||
# || AK4 genjets		Number:   8					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 1748.3195
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167566
# PV  X: -0.025 Y: 0.068 Z: -1.961 nDoF: 95.500 Chi^2: 1.035
# ==============================================================================
# || Secondary Vertices	Number:   2 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	39.750	1.640	3.121	0.980	4.688	1.826	0.765		    ||
# ||	5.402	0.256	0.526	1.637	0.889	0.907	0.067		    ||
# ==============================================================================
# || Muons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	77.665	1.551	1.354	0.001	0.000	0.002	    0	0.003	    ||
# ==============================================================================
# || Electrons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso03  ||
# ||	8.323	-1.825	-0.829	0.404	-0.062	-1.270	   -1	0.302	    ||
# ==============================================================================
# || Photons		Number:   0					    ||
# ==============================================================================
# || AK4 Jets		Number:   7					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	89.750	1.545	1.351	0.100	-0.983	    6	0.000	0.015	    ||
# ||	69.938	0.237	0.520	0.422	-0.379	    6	0.000	0.332	    ||
# ||	65.750	1.629	3.121	0.967	0.941	    6	0.000	0.828	    ||
# ||	61.469	1.294	-0.774	0.136	-0.937	    6	0.000	0.664	    ||
# ||	41.594	0.286	-1.987	0.511	-0.728	    6	0.000	0.449	    ||
# ||	37.062	1.762	-2.691	0.208	-0.884	    6	0.000	0.898	    ||
# ||	16.828	0.463	-1.331	0.214	-0.895	    6	0.000	0.805	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  45					    ||
# || AK4 genjets		Number:   7					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 616.8573
#
#
#
# Run:        1 	LuminosityBlock:       59 	Event:   167608
# PV  X: -0.024 Y: 0.070 Z: -7.857 nDoF: 103.000 Chi^2: 0.742
# ==============================================================================
# || Secondary Vertices	Number:   2 					    ||
# ||	   Pt	  Eta	  Phi	 Chi2	 nDoF	 Mass	 dLen		    ||
# ||	2.701	-1.222	0.583	0.205	0.938	0.569	0.115		    ||
# ||	2.631	-1.391	-0.923	0.339	2.883	0.977	0.142		    ||
# ==============================================================================
# || Muons		Number:   1					    ||
# ||	   Pt	  Eta	  Phi	 IP3d	  dXY	   dZ	JetID	PFRelIso04  ||
# ||	66.509	-1.441	2.374	0.001	0.000	0.002	    0	0.000	    ||
# ==============================================================================
# || Electrons		Number:   0					    ||
# ==============================================================================
# || Photons		Number:   0					    ||
# ==============================================================================
# || AK4 Jets		Number:   7					    ||
# ||	   Pt	  Eta	  Phi	CSVv2	 CMVA	JetID	ChEmEF	ChHEF       ||
# ||	73.750	-1.443	2.379	0.085	-0.983	    6	0.000	0.022	    ||
# ||	48.719	-0.271	-2.768	0.099	-0.984	    6	0.000	0.625	    ||
# ||	36.594	-1.157	0.429	0.575	-0.438	    6	0.000	0.449	    ||
# ||	33.531	-1.462	-1.716	0.191	-0.961	    6	0.000	0.375	    ||
# ||	29.234	-0.685	-0.554	0.721	-0.129	    6	0.000	0.742	    ||
# ||	21.516	-0.903	-0.959	0.139	-0.960	    6	0.000	0.547	    ||
# ||	16.125	-2.878	-0.203	-10.000	-0.853	    6	0.000	0.043	    ||
# ==============================================================================
# || AK8 Jets		Number:   0					    ||
# ==============================================================================
# || AK8 SubJets		Number:   0					    ||
# ==============================================================================
# || Gen particles	Number:  43					    ||
# || AK4 genjets		Number:   7					    ||
# || AK8 genjets		Number:   0					    ||
# || AK8 genSubjets	Number:   0					    ||
# ==============================================================================
# Event Mass: 384.9844
#
# Processed    10000/  636713 entries (elapsed time     1.2s, curr speed    8.696 kHz, avg speed    8.696 kHz), accepted       10/   10001 events ( 0.10%)
# Processed    20000/  636713 entries (elapsed time     1.5s, curr speed   27.778 kHz, avg speed   13.245 kHz), accepted       10/   20001 events ( 0.05%)
# Processed    30000/  636713 entries (elapsed time     1.9s, curr speed   27.778 kHz, avg speed   16.043 kHz), accepted       10/   30001 events ( 0.03%)
# Processed    40000/  636713 entries (elapsed time     2.2s, curr speed   29.412 kHz, avg speed   18.100 kHz), accepted       10/   40001 events ( 0.02%)
# Processed    50000/  636713 entries (elapsed time     2.5s, curr speed   29.412 kHz, avg speed   19.608 kHz), accepted       10/   50001 events ( 0.02%)
# Processed    60000/  636713 entries (elapsed time     2.9s, curr speed   27.778 kHz, avg speed   20.619 kHz), accepted       10/   60001 events ( 0.02%)
# Processed    70000/  636713 entries (elapsed time     3.2s, curr speed   29.412 kHz, avg speed   21.538 kHz), accepted       10/   70001 events ( 0.01%)
# Processed    80000/  636713 entries (elapsed time     3.6s, curr speed   27.778 kHz, avg speed   22.161 kHz), accepted       10/   80001 events ( 0.01%)
# Processed    90000/  636713 entries (elapsed time     4.0s, curr speed   28.571 kHz, avg speed   22.727 kHz), accepted       10/   90001 events ( 0.01%)
# Processed   100000/  636713 entries (elapsed time     4.3s, curr speed   26.316 kHz, avg speed   23.041 kHz), accepted       10/  100001 events ( 0.01%)
# Processed   110000/  636713 entries (elapsed time     4.7s, curr speed   27.027 kHz, avg speed   23.355 kHz), accepted       10/  110001 events ( 0.01%)
# Processed   120000/  636713 entries (elapsed time     5.1s, curr speed   26.316 kHz, avg speed   23.576 kHz), accepted       10/  120001 events ( 0.01%)
# Processed   130000/  636713 entries (elapsed time     5.5s, curr speed   26.316 kHz, avg speed   23.766 kHz), accepted       10/  130001 events ( 0.01%)
# Processed   140000/  636713 entries (elapsed time     5.8s, curr speed   27.027 kHz, avg speed   23.973 kHz), accepted       10/  140001 events ( 0.01%)
# Processed   150000/  636713 entries (elapsed time     6.2s, curr speed   28.571 kHz, avg speed   24.233 kHz), accepted       10/  150001 events ( 0.01%)
# Processed   160000/  636713 entries (elapsed time     6.6s, curr speed   27.027 kHz, avg speed   24.390 kHz), accepted       10/  160001 events ( 0.01%)
# Processed   170000/  636713 entries (elapsed time     7.0s, curr speed   25.000 kHz, avg speed   24.425 kHz), accepted       10/  170001 events ( 0.01%)
# Processed   180000/  636713 entries (elapsed time     7.3s, curr speed   27.027 kHz, avg speed   24.557 kHz), accepted       10/  180001 events ( 0.01%)
# Processed   190000/  636713 entries (elapsed time     7.7s, curr speed   27.778 kHz, avg speed   24.707 kHz), accepted       10/  190001 events ( 0.01%)
# Processed   200000/  636713 entries (elapsed time     8.0s, curr speed   28.571 kHz, avg speed   24.876 kHz), accepted       10/  200001 events ( 0.00%)
# Processed   210000/  636713 entries (elapsed time     8.4s, curr speed   27.778 kHz, avg speed   25.000 kHz), accepted       10/  210001 events ( 0.00%)
# Processed   220000/  636713 entries (elapsed time     8.8s, curr speed   27.778 kHz, avg speed   25.114 kHz), accepted       10/  220001 events ( 0.00%)
# Processed   230000/  636713 entries (elapsed time     9.1s, curr speed   26.316 kHz, avg speed   25.164 kHz), accepted       10/  230001 events ( 0.00%)
# Processed   240000/  636713 entries (elapsed time     9.5s, curr speed   27.778 kHz, avg speed   25.263 kHz), accepted       10/  240001 events ( 0.00%)
# Processed   250000/  636713 entries (elapsed time     9.9s, curr speed   27.778 kHz, avg speed   25.355 kHz), accepted       10/  250001 events ( 0.00%)
# Processed   260000/  636713 entries (elapsed time    10.2s, curr speed   27.027 kHz, avg speed   25.415 kHz), accepted       10/  260001 events ( 0.00%)
# Processed   270000/  636713 entries (elapsed time    10.6s, curr speed   26.316 kHz, avg speed   25.448 kHz), accepted       10/  270001 events ( 0.00%)
# Processed   280000/  636713 entries (elapsed time    11.0s, curr speed   29.412 kHz, avg speed   25.571 kHz), accepted       10/  280001 events ( 0.00%)
# Processed   290000/  636713 entries (elapsed time    11.3s, curr speed   25.641 kHz, avg speed   25.573 kHz), accepted       10/  290001 events ( 0.00%)
# Processed   300000/  636713 entries (elapsed time    11.7s, curr speed   26.316 kHz, avg speed   25.597 kHz), accepted       10/  300001 events ( 0.00%)
# Processed   310000/  636713 entries (elapsed time    12.1s, curr speed   27.027 kHz, avg speed   25.641 kHz), accepted       10/  310001 events ( 0.00%)
# Processed   320000/  636713 entries (elapsed time    12.5s, curr speed   26.316 kHz, avg speed   25.662 kHz), accepted       10/  320001 events ( 0.00%)
# Processed   330000/  636713 entries (elapsed time    12.8s, curr speed   28.571 kHz, avg speed   25.741 kHz), accepted       10/  330001 events ( 0.00%)
# Processed   340000/  636713 entries (elapsed time    13.2s, curr speed   27.778 kHz, avg speed   25.797 kHz), accepted       10/  340001 events ( 0.00%)
# Processed   350000/  636713 entries (elapsed time    13.6s, curr speed   26.316 kHz, avg speed   25.811 kHz), accepted       10/  350001 events ( 0.00%)
# Processed   360000/  636713 entries (elapsed time    13.9s, curr speed   28.571 kHz, avg speed   25.881 kHz), accepted       10/  360001 events ( 0.00%)
# Processed   370000/  636713 entries (elapsed time    14.3s, curr speed   24.390 kHz, avg speed   25.838 kHz), accepted       10/  370001 events ( 0.00%)
# Processed   380000/  636713 entries (elapsed time    14.7s, curr speed   26.316 kHz, avg speed   25.850 kHz), accepted       10/  380001 events ( 0.00%)
# Processed   390000/  636713 entries (elapsed time    15.1s, curr speed   25.000 kHz, avg speed   25.828 kHz), accepted       10/  390001 events ( 0.00%)
# Processed   400000/  636713 entries (elapsed time    15.5s, curr speed   25.000 kHz, avg speed   25.806 kHz), accepted       10/  400001 events ( 0.00%)
# Processed   410000/  636713 entries (elapsed time    15.9s, curr speed   27.778 kHz, avg speed   25.851 kHz), accepted       10/  410001 events ( 0.00%)
# Processed   420000/  636713 entries (elapsed time    16.2s, curr speed   27.027 kHz, avg speed   25.878 kHz), accepted       10/  420001 events ( 0.00%)
# Processed   430000/  636713 entries (elapsed time    16.6s, curr speed   28.571 kHz, avg speed   25.935 kHz), accepted       10/  430001 events ( 0.00%)
# Processed   440000/  636713 entries (elapsed time    17.0s, curr speed   25.641 kHz, avg speed   25.928 kHz), accepted       10/  440001 events ( 0.00%)
# Processed   450000/  636713 entries (elapsed time    17.3s, curr speed   27.778 kHz, avg speed   25.967 kHz), accepted       10/  450001 events ( 0.00%)
# Processed   460000/  636713 entries (elapsed time    17.7s, curr speed   27.027 kHz, avg speed   25.989 kHz), accepted       10/  460001 events ( 0.00%)
# Processed   470000/  636713 entries (elapsed time    18.1s, curr speed   25.641 kHz, avg speed   25.981 kHz), accepted       10/  470001 events ( 0.00%)
# Processed   480000/  636713 entries (elapsed time    18.5s, curr speed   25.641 kHz, avg speed   25.974 kHz), accepted       10/  480001 events ( 0.00%)
# Processed   490000/  636713 entries (elapsed time    18.9s, curr speed   26.316 kHz, avg speed   25.981 kHz), accepted       10/  490001 events ( 0.00%)
# Processed   500000/  636713 entries (elapsed time    19.2s, curr speed   27.027 kHz, avg speed   26.001 kHz), accepted       10/  500001 events ( 0.00%)
# Processed   510000/  636713 entries (elapsed time    19.6s, curr speed   26.316 kHz, avg speed   26.007 kHz), accepted       10/  510001 events ( 0.00%)
# Processed   520000/  636713 entries (elapsed time    20.0s, curr speed   27.027 kHz, avg speed   26.026 kHz), accepted       10/  520001 events ( 0.00%)
# Processed   530000/  636713 entries (elapsed time    20.3s, curr speed   27.778 kHz, avg speed   26.057 kHz), accepted       10/  530001 events ( 0.00%)
# Processed   540000/  636713 entries (elapsed time    20.7s, curr speed   27.027 kHz, avg speed   26.074 kHz), accepted       10/  540001 events ( 0.00%)
# Processed   550000/  636713 entries (elapsed time    21.0s, curr speed   29.412 kHz, avg speed   26.128 kHz), accepted       10/  550001 events ( 0.00%)
# Processed   560000/  636713 entries (elapsed time    21.4s, curr speed   27.027 kHz, avg speed   26.144 kHz), accepted       10/  560001 events ( 0.00%)
# Processed   570000/  636713 entries (elapsed time    21.8s, curr speed   27.778 kHz, avg speed   26.171 kHz), accepted       10/  570001 events ( 0.00%)
# Processed   580000/  636713 entries (elapsed time    22.1s, curr speed   27.778 kHz, avg speed   26.197 kHz), accepted       10/  580001 events ( 0.00%)
# Processed   590000/  636713 entries (elapsed time    22.5s, curr speed   27.778 kHz, avg speed   26.222 kHz), accepted       10/  590001 events ( 0.00%)
# Processed   600000/  636713 entries (elapsed time    22.9s, curr speed   25.000 kHz, avg speed   26.201 kHz), accepted       10/  600001 events ( 0.00%)
# Processed   610000/  636713 entries (elapsed time    23.3s, curr speed   26.316 kHz, avg speed   26.203 kHz), accepted       10/  610001 events ( 0.00%)
# Processed   620000/  636713 entries (elapsed time    23.7s, curr speed   26.316 kHz, avg speed   26.205 kHz), accepted       10/  620001 events ( 0.00%)
# Processed   630000/  636713 entries (elapsed time    24.0s, curr speed   25.641 kHz, avg speed   26.195 kHz), accepted       10/  630001 events ( 0.00%)
# Processed 636713 preselected entries from root://cms-xrd-global.cern.ch//store/mc/RunIIFall17NanoAOD/TTJets_SingleLeptFromT_TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/00000/06CC0D9B-4244-E811-8B62-485B39897212.root (696370 entries). Finally selected 10 entries
# 27622.7687426 Hz
